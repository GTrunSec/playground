# %%
nix develop ../..#tullia --command tullia run julia-cli --runtime unwrapped --log-level info
# Out:
# ...
# path '/home/gtrun/ghq/github.com/GTrunSec/DeSci/playground/notebooks' does not contain a 'flake.nix', searching up
# error: path '/home/gtrun/ghq/github.com/GTrunSec/DeSci/playground' is not part of a flake (neither it nor its parent directories contain a 'flake.nix' file)
# 8:50PM FTL creating supervisor error="running eval: exit status 1"
# : 1

# %%
nix develop ..#tullia --command tullia run ci --runtime nsjail --log-level info
# Out:
# ...
# path '/home/gtrun/ghq/github.com/GTrunSec/DeSci/notebooks' does not contain a 'flake.nix', searching up
# ...
# [+] wait   ci         0.0s
# [+] build  julia      0.0s
# [+] build  update     0.0s
#                                                                                 [+] build  ci         0.0s
# [+] build  ci         0.1s
# [+] build  julia      0.1s
# [+] build  update     0.1s
# [+] build  ci         0.2s
# [+] build  julia      0.2s
# [+] build  update     0.2s
# [+] build  ci         0.3s
# [+] build  julia      0.3s
# [+] build  update     0.3s
# [+] build  ci         0.4s
# [+] build  julia      0.4s
# [+] build  update     0.4s
# [+] build  ci         0.5s
# [+] build  julia      0.5s
# [+] build  update     0.5s
# [+] build  ci         0.6s
# [+] build  julia      0.6s
# [+] build  update     0.6s
# [+] build  ci         0.7s
# [+] build  julia      0.7s
# [+] build  update     0.7s
# [+] build  ci         0.8s
# [+] build  julia      0.8s
# [+] build  update     0.8s
# ...

# %%
nix develop ..#tullia --command tullia run julia-cli --runtime nsjail --log-level info
# Out:
# ...
# path '/home/gtrun/ghq/github.com/GTrunSec/DeSci/notebooks' does not contain a 'flake.nix', searching up
# ...
# [+] build  julia-cli  0.0s
#                                                                                 [+] build  julia-cli  0.1s
# [+] build  julia-cli  0.2s
# [+] build  julia-cli  0.3s
# [+] build  julia-cli  0.4s
# [+] build  julia-cli  0.5s
# [+] build  julia-cli  0.6s
# [+] build  julia-cli  0.7s
# [+] build  julia-cli  0.8s
# [+] build  julia-cli  0.9s
# [+] build  julia-cli  1.0s
# [+] build  julia-cli  1.1s
# [+] build  julia-cli  1.2s
# [+] build  julia-cli  1.3s
# [+] build  julia-cli  1.4s
# [+] build  julia-cli  1.5s
# [+] build  julia-cli  1.6s
# [+] build  julia-cli  1.7s
# [+] build  julia-cli  1.8s
# [+] build  julia-cli  1.9s
# [+] build  julia-cli  2.0s
# [+] build  julia-cli  2.1s
# [+] build  julia-cli  2.2s
# [+] build  julia-cli  2.3s
# [+] build  julia-cli  2.4s
# [+] build  julia-cli  2.5s
# [+] build  julia-cli  2.6s
# [+] build  julia-cli  2.7s
# ...

# %%
export PATH=/run/wrappers/bin:$PATH

# %%
nix develop ..#tullia --command tullia run julia-cli --runtime podman --log-level info
# Out:
# ...
# path '/home/gtrun/ghq/github.com/GTrunSec/DeSci/notebooks' does not contain a 'flake.nix', searching up
# ...
# [+] build  julia-cli  0.0s
#                                                                                 [+] build  julia-cli  0.1s
# [+] build  julia-cli  0.2s
# [+] build  julia-cli  0.3s
# [+] build  julia-cli  0.4s
# [+] build  julia-cli  0.5s
# [+] build  julia-cli  0.6s
# [+] build  julia-cli  0.7s
# [+] build  julia-cli  0.8s
# [+] build  julia-cli  0.9s
# [+] build  julia-cli  1.0s
# [+] build  julia-cli  1.1s
# [+] build  julia-cli  1.2s
# [+] build  julia-cli  1.3s
# [+] build  julia-cli  1.4s
# [+] build  julia-cli  1.5s
# [+] build  julia-cli  1.6s
# [+] build  julia-cli  1.7s
# [+] build  julia-cli  1.8s
# [+] build  julia-cli  1.9s
# [+] build  julia-cli  2.0s
# [+] build  julia-cli  2.1s
# [+] build  julia-cli  2.2s
# [+] build  julia-cli  2.3s
# [+] build  julia-cli  2.4s
# [+] build  julia-cli  2.5s
# [+] build  julia-cli  2.6s
# [+] build  julia-cli  2.7s
# ...

# %%
nu --version
# Out:
# 0.72.0

# %%
nu -c 'vast export -n 1 json | from json'
# Out:
# Error: ]8;;https://docs.rs/nu-parser/0.72.0/nu_parser/enum.ParseError.html#variant.RegisteredFileNotFound\nu::parser::registered_file_not_found (link)]8;;\
#
#   × File not found
#    ╭─[/home/gtrun/.config/nushell/plugin.nu:1:1]
#  1 │ register /nix/store/ww5qlgpfn4bkpa3d42j0gp6vqpximrhy-nu-plugin-from-parquet-eb32b24527ec171f07385511271e937f314ee1f5/bin/nu_plugin_from_parquet  {
#    ·          ───────────────────────────────────────────────────────────────────┬──────────────────────────────────────────────────────────────────
#    ·                                                                             ╰── File not found: /nix/store/ww5qlgpfn4bkpa3d42j0gp6vqpximrhy-nu-plugin-from-parquet-eb32b24527ec171f07385511271e937f314ee1f5/bin/nu_plugin_from_parquet
#  2 │   "name": "from parquet",
#    ╰────
#   help: registered files need to be available before your script is run
#
# [21:11:50.963] client connects to VAST node at 127.0.0.1:42000/tcp
# ...
